# %%
# Assignment q 2.3
# 18PHD0140
# Flower classification using NAIVE BAYES

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
data = pd.read_csv('C:/Users/Acer/Desktop/iris.csv')

# %%
#looking at the first 5 values of the dataset
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/Acer/Desktop/iris_flowers.jpg')
imgplot = plt.imshow(img)
plt.show()

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
data.isnull().values.any()
# Out:
# False

# %%
data.iloc[:,0:4]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0      1            5.1           3.5            1.4
# 1      2            4.9           3.0            1.4
# 2      3            4.7           3.2            1.3
# 3      4            4.6           3.1            1.5
# 4      5            5.0           3.6            1.4
# 5      6            5.4           3.9            1.7
# 6      7            4.6           3.4            1.4
# 7      8            5.0           3.4            1.5
# 8      9            4.4           2.9            1.4
# 9     10            4.9           3.1            1.5
# 10    11            5.4           3.7            1.5
# 11    12            4.8           3.4            1.6
# 12    13            4.8           3.0            1.4
# 13    14            4.3           3.0            1.1
# 14    15            5.8           4.0            1.2
# 15    16            5.7           4.4            1.5
# 16    17            5.4           3.9            1.3
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data.iloc[:,0:4],data['Species'],test_size=0.3)

# %%
x_train.shape,y_train.shape
# Out:
# ((105, 4), (105,))

# %%
x_test.shape,y_test.shape
# Out:
# ((45, 4), (45,))

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
x_train = scaler.fit_transform(x_train)
x_test= scaler.transform(x_test)

# %%
x_train,x_train.shape
# Out:
# (array([[0.30872483, 0.22222222, 0.72727273, 0.10169492],
#         [0.33557047, 0.75      , 0.45454545, 0.62711864],
#         [0.81879195, 0.94444444, 0.27272727, 0.96610169],
#         [0.43624161, 0.66666667, 0.40909091, 0.57627119],
#         [0.83892617, 0.80555556, 0.45454545, 0.84745763],
#         [0.79865772, 0.47222222, 0.        , 0.6779661 ],
#         [0.53691275, 0.33333333, 0.09090909, 0.47457627],
#         [0.10738255, 0.30555556, 0.77272727, 0.05084746],
#         [0.76510067, 0.41666667, 0.27272727, 0.69491525],
#         [0.08724832, 0.        , 0.36363636, 0.01694915],
#         [0.11409396, 0.22222222, 0.59090909, 0.06779661],
#         [0.89261745, 0.55555556, 0.27272727, 0.69491525],
#         [0.69798658, 0.61111111, 0.36363636, 0.81355932],
#         [0.46308725, 0.36111111, 0.13636364, 0.49152542],
#         [0.28187919, 0.02777778, 0.45454545, 0.05084746],
#         [0.12080537, 0.38888889, 0.72727273, 0.11864407],
# ...

# %%
x_test,x_test.shape
# Out:
# (array([[ 0.38926174,  0.63888889,  0.31818182,  0.61016949],
#         [ 0.48322148,  0.55555556,  0.13636364,  0.66101695],
#         [ 0.55704698,  0.47222222,  0.22727273,  0.69491525],
#         [ 0.68456376,  0.77777778,  0.36363636,  0.83050847],
#         [ 0.41610738,  0.47222222,  0.        ,  0.50847458],
#         [ 0.77852349,  0.61111111,  0.36363636,  0.76271186],
#         [ 0.44966443,  0.41666667,  0.22727273,  0.52542373],
#         [ 0.04026846,  0.08333333,  0.54545455,  0.06779661],
#         [ 0.03355705,  0.30555556,  0.77272727,  0.11864407],
#         [ 0.93959732,  0.66666667,  0.40909091,  0.77966102],
#         [ 0.19463087,  0.11111111,  0.45454545,  0.10169492],
#         [ 0.69127517,  0.55555556,  0.31818182,  0.77966102],
#         [ 0.34228188,  0.58333333,  0.45454545,  0.59322034],
#         [ 0.01342282,  0.11111111,  0.45454545,  0.05084746],
#         [ 0.37583893,  0.55555556,  0.5       ,  0.62711864],
# ...

# %%
data=pd.DataFrame(x_train)
data
# Out:
#             0         1         2         3
# 0    0.308725  0.222222  0.727273  0.101695
# 1    0.335570  0.750000  0.454545  0.627119
# 2    0.818792  0.944444  0.272727  0.966102
# 3    0.436242  0.666667  0.409091  0.576271
# 4    0.838926  0.805556  0.454545  0.847458
# 5    0.798658  0.472222  0.000000  0.677966
# 6    0.536913  0.333333  0.090909  0.474576
# 7    0.107383  0.305556  0.772727  0.050847
# 8    0.765101  0.416667  0.272727  0.694915
# 9    0.087248  0.000000  0.363636  0.016949
# 10   0.114094  0.222222  0.590909  0.067797
# 11   0.892617  0.555556  0.272727  0.694915
# 12   0.697987  0.611111  0.363636  0.813559
# 13   0.463087  0.361111  0.136364  0.491525
# 14   0.281879  0.027778  0.454545  0.050847
# 15   0.120805  0.388889  0.727273  0.118644
# 16   0.275168  0.055556  0.045455  0.050847
# 17   0.577181  0.666667  0.409091  0.627119
# 18   0.355705  0.333333  0.045455  0.508475
# 19   0.523490  0.472222  0.318182  0.593220
# ...

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC()

# %%
svc_model.fit(x_train,y_train)
# Out:
# C:\Users\Acer\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
predictions = svc_model.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[10  0  0]
#  [ 0 21  0]
#  [ 0  0 14]]

# %%
print(classification_report(y_test,predictions))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        10
# Iris-versicolor       1.00      1.00      1.00        21
#  Iris-virginica       1.00      1.00      1.00        14
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
